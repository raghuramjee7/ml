# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
pd.plotting.register_matplotlib_converters()

print("Setup Done")
# Out:
# Setup Done

# %%
df_path = "C:/Users/SAKET/Downloads/output.csv"

df = pd.read_csv(df_path)

# %%
df.head()
# Out:
#    Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0      44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
# 1      47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2      64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3      67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 4       NaN  0.598516  0.087839      NaN       0.0       NaN  0.392104
#
#    Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  Feature14  \
# 0  5.166124  2.277942        NaN          5         X          1  Category1
# 1  0.450312 -3.395356        NaN          3         X          0  Category1
# 2  6.786555 -3.070746        NaN          7         Z          0  Category1
# 3  1.937158 -0.246269   6.004975         20         X          0  Category1
# 4  4.010937  3.215086   2.891199          3         Z          0  Category1
#
#   Feature15  Feature16  Feature17 Feature18 Feature19 Feature20
# ...

# %%
df.shape
# Out:
# (5000, 20)

# %%
df = df[:500]

# %%
df.shape
# Out:
# (500, 20)

# %%
df.describe()
# Out:
#         Feature1  Feature2  Feature3  Feature5   Feature6  Feature7  Feature8  \
# count   4.000000  5.000000  5.000000       2.0    3.00000  5.000000  5.000000
# mean   55.500000  0.419377 -0.336238       0.0  266.00000  1.215898  3.670217
# std    11.676187  0.308310  0.642370       0.0  180.17769  0.707905  2.521739
# min    44.000000  0.026838 -1.014799       0.0  158.00000  0.392104  0.450312
# 25%    46.250000  0.199990 -0.958091       0.0  162.00000  0.635091  1.937158
# 50%    55.500000  0.474124 -0.244178       0.0  166.00000  1.410613  4.010937
# 75%    64.750000  0.598516  0.087839       0.0  320.00000  1.490148  5.166124
# max    67.000000  0.797417  0.448040       0.0  474.00000  2.151535  6.786555
#
#        Feature9  Feature10  Feature11  Feature13  Feature16  Feature17
# count  5.000000   2.000000   5.000000   5.000000   2.000000   5.000000
# mean  -0.243868   4.448087   7.600000   0.200000  10.041858  10.602374
# ...

# %%
df.dtypes
# Out:
# Feature1     float64
# Feature2     float64
# Feature3     float64
# Feature4      object
# Feature5     float64
# Feature6     float64
# Feature7     float64
# Feature8     float64
# Feature9     float64
# Feature10    float64
# Feature11      int64
# Feature12     object
# Feature13      int64
# Feature14     object
# Feature15     object
# Feature16    float64
# Feature17    float64
# Feature18     object
# Feature19     object
# Feature20     object
# dtype: object

# %% [markdown]
# ### Lineplots

# %%
plt.figure(figsize=(16,16)) # setting width and height of the figure
plt.title("Demo Title") # set title

sns.lineplot(data=df)
# Out:
# <Axes: title={'center': 'Demo Title'}>

# %%
df.columns
# Out:
# Index(['Feature1', 'Feature2', 'Feature3', 'Feature4', 'Feature5', 'Feature6',
#        'Feature7', 'Feature8', 'Feature9', 'Feature10', 'Feature11',
#        'Feature12', 'Feature13', 'Feature14', 'Feature15', 'Feature16',
#        'Feature17', 'Feature18', 'Feature19', 'Feature20'],
#       dtype='object')

# %%
plt.figure(figsize=(14,16))

plt.title("Demo for col names")

sns.lineplot(data = df["Feature16"], label = "Feature A") # put the column as data, and give its name
sns.lineplot(data = df["Feature17"], label = "Feature B")

plt.xlabel("X Label") # Name X axis
plt.ylabel("Y Label") # Name Y axis
# Out:
# Text(0, 0.5, 'Y Label')

# %% [markdown]
# ### Barplots

# %%
dum_df = df[:5]

# %%
dum_df
# Out:
#    Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0      44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
# 1      47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2      64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3      67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 4       NaN  0.598516  0.087839      NaN       0.0       NaN  0.392104
#
#    Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  Feature14  \
# 0  5.166124  2.277942        NaN          5         X          1  Category1
# 1  0.450312 -3.395356        NaN          3         X          0  Category1
# 2  6.786555 -3.070746        NaN          7         Z          0  Category1
# 3  1.937158 -0.246269   6.004975         20         X          0  Category1
# 4  4.010937  3.215086   2.891199          3         Z          0  Category1
#
#   Feature15  Feature16  Feature17 Feature18 Feature19 Feature20
# ...

# %%
plt.figure(figsize=(10,6))

sns.barplot(x = dum_df.index, y = dum_df["Feature2"])
# Out:
# <Axes: ylabel='Feature2'>

# %% [markdown]
# ### Heatmaps

# %%
plt.figure(figsize=(10, 5))

cols = ["Feature2", "Feature7", "Feature8", "Feature9"]

sns.heatmap(data = dum_df[cols], annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Scatter Plots

# %%
sns.scatterplot(x = dum_df["Feature2"], y = dum_df["Feature7"])
# Out:
# <Axes: xlabel='Feature2', ylabel='Feature7'>

# %%
# we can also create reg plots
sns.regplot(x = dum_df["Feature2"], y = dum_df["Feature7"])
# Out:
# <Axes: xlabel='Feature2', ylabel='Feature7'>

# %%
sns.scatterplot(x = dum_df["Feature2"], y = dum_df["Feature7"], hue = dum_df["Feature9"]) 
# here feature9 is the value on which points coincide at

# we can also write scatterplots as
sns.lmplot(x = "bmi", y = "charges", hue = "smoker", data = df)

# swarmplots
sns.swarmplot(x = dum_df["Feature2"], y = dum_df["Feature8"])

# %% [markdown]
# ### Histogram

# %%
sns.histplot(dum_df["Feature2"])
# Out:
# <Axes: xlabel='Feature2', ylabel='Count'>

# %%
# kdeplot
sns.set_style("dark") # white, dark, whitegrid, darkgrid, ticks

sns.kdeplot(dum_df["Feature2"], shade = True)
# Out:
# C:\Users\SAKET\AppData\Local\Temp\ipykernel_10688\3228507403.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dum_df["Feature2"], shade = True)
# <Axes: xlabel='Feature2', ylabel='Density'>

# %%
# we can join multiple KDE plots
sns.set_style("dark")
sns.jointplot(x = dum_df["Feature2"], y = dum_df["Feature7"], kind = "kde") # the kind can be anything

# %%
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)

# %%
# Code for kaggle
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
