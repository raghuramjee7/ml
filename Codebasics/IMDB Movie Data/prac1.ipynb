# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv("IMDB-Movie-Data.csv")
movies.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
print(movies.info())
print(movies.describe())
print(movies.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 74.3+ KB
# None
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# ...

# %%
print(movies['Title'].head(10))
print(movies[['Genre','Title']].head(5))
# Out:
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# 5             The Great Wall
# 6                 La La Land
# 7                   Mindhorn
# 8         The Lost City of Z
# 9                 Passengers
# Name: Title, dtype: object
#                       Genre                    Title
# 0   Action,Adventure,Sci-Fi  Guardians of the Galaxy
# 1  Adventure,Mystery,Sci-Fi               Prometheus
# 2           Horror,Thriller                    Split
# 3   Animation,Comedy,Family                     Sing
# 4  Action,Adventure,Fantasy            Suicide Squad

# %%
x = movies.loc[:3,:]
print(x)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# ...

# %%
df = movies[movies['Rating']==9]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 54 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1 non-null      int64
#  1   Title               1 non-null      object
#  2   Genre               1 non-null      object
#  3   Description         1 non-null      object
#  4   Director            1 non-null      object
#  5   Actors              1 non-null      object
#  6   Year                1 non-null      int64
#  7   Runtime (Minutes)   1 non-null      int64
#  8   Rating              1 non-null      float64
#  9   Votes               1 non-null      int64
#  10  Revenue (Millions)  1 non-null      float64
#  11  Metascore           1 non-null      float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.0+ bytes

# %%
movies.groupby('Director')[['Rating', 'Revenue (Millions)']].mean().tail(5)
# Out:
#                   Rating  Revenue (Millions)
# Director
# Xavier Dolan        7.55               3.490
# Yimou Zhang         6.10              45.130
# Yorgos Lanthimos    7.20               4.405
# Zack Snyder         7.04             195.148
# Zackary Adler       5.10               6.530

# %%
x = movies.groupby('Director')[['Rating', 'Revenue (Millions)']].max().sort_values(['Revenue (Millions)'], ascending = False).head(5)
x
# Out:
#                    Rating  Revenue (Millions)
# Director
# J.J. Abrams           8.1              936.63
# James Cameron         7.8              760.51
# Colin Trevorrow       7.0              652.18
# Joss Whedon           8.1              623.28
# Christopher Nolan     9.0              533.32

# %%
movies.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
movies.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
movies.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
movies.fillna(0, inplace = True)
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
movies.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
df = movies.pivot_table('Rating', index = 'Director', aggfunc='max', columns='Year').head()
mean = df.mean()
df.fillna(mean, inplace = True)
df
# Out:
# Year                 2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# Director
# Aamir Khan            6.6   8.5   6.9   NaN   6.7   NaN   5.9   7.8   NaN
# Abdellatif Kechiche   6.6   7.6   6.9   NaN   6.7   NaN   5.9   7.8   NaN
# Adam Leon             6.6   7.6   6.9   NaN   6.7   NaN   5.9   7.8   NaN
# Adam McKay            6.6   7.6   6.9   NaN   6.7   NaN   5.9   7.8   NaN
# Adam Shankman         6.6   6.7   6.9   NaN   6.7   NaN   5.9   7.8   NaN
#
# Year                 2015  2016
# Director
# Aamir Khan            7.8   6.5
# Abdellatif Kechiche   7.8   6.5
# Adam Leon             7.8   6.5
# Adam McKay            7.8   6.5
# Adam Shankman         7.8   6.5
